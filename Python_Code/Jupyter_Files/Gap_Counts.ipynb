# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gap_counts.txt")

# %%
df
# Out:
#        gap  value
# 0      0.0     90
# 1      1.0     90
# 2      2.0     90
# 3      3.0     90
# 4      4.0     90
# 5      5.0     90
# 6      6.0     90
# 7      7.0     90
# 8      8.0     90
# 9      9.0     90
# 10    10.0     90
# 11    11.0     90
# 12    12.0     90
# 13    13.0     91
# 14    14.0     91
# 15    15.0     91
# 16    16.0     91
# 17    17.0     91
# 18    18.0     90
# 19    19.0     90
# 20    20.0     90
# 21    21.0     90
# 22    22.0     90
# 23    23.0     90
# 24    24.0     90
# 25    25.0     90
# 26    26.0     90
# 27    27.0     90
# 28    28.0     89
# 29    29.0     88
# ..     ...    ...
# 970  970.0   1630
# 971  971.0   1630
# 972  972.0   1631
# 973  973.0   1632
# 974  974.0   1634
# 975  975.0   1634
# 976  976.0   1641
# 977  977.0   1625
# 978  978.0   1629
# 979  979.0   1630
# 980  980.0   1632
# 981  981.0   1634
# 982  982.0   1634
# 983  983.0   1634
# 984  984.0   1635
# 985  985.0   1636
# 986  986.0   1716
# 987  987.0   1719
# ...

# %%
plt.figure(figsize=(15, 7 )) 
ax = plt.gca()
df.plot(kind='line',x='gap' ,y='value',ax=ax)

plt.xlabel("gap (ms)")
plt.ylabel('counts')

plt.show()
